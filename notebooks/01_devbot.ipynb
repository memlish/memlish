# %%
# !python /app/apps/bot/main.py
# Out:
# 2022-02-06 16:00:58,651 [worker_pid=77] Bot: onlymemes [@onlymemebot]
# 2022-02-06 16:00:59,857 [worker_pid=77] Updates were skipped successfully.
# 2022-02-06 16:00:59,857 [worker_pid=77] Start polling.
# 2022-02-06 16:02:34,147 [worker_pid=77] Received inline query [ID:1187924785364615132] from user [ID:276585292]
# 2022-02-06 16:02:37,977 [worker_pid=77] Received inline query [ID:1187924786456325242] from user [ID:276585292]
# {'update': '{"id": "1187924786456325242", "from": {"id": 276585292, "is_bot": false, "first_name": "Daniel", "last_name": "Kovalenko", "username": "daniel_kovalenko", "language_code": "en"}, "chat_type": "private", "query": "qwert", "offset": ""}', 'template_options': ["(image['template_name']+'__'+str(uuid4()))[:63]"]}
# 2022-02-06 16:02:37,978 [worker_pid=77] Process update [ID:734871206]: [success] (in 1 ms)
# 2022-02-06 16:02:45,441 [worker_pid=77] Received inline query [ID:1187924787343302040] from user [ID:276585292]
# ...
